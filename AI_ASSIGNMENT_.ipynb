# %% [markdown]
# <a href="https://colab.research.google.com/github/pmuskan/DNA-sequencing/blob/main/AI_ASSIGNMENT_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PERFORMING UNIVARIATE,BIVARIATE AND MULTIVARIATE ANALYSIS USING HOUSING DATASET.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt
import seaborn as sns

# %%
def countplot(dataframe, x_val, plot_title='', figsize=(15,8)):
    plt.figure(figsize=figsize)
    plt.title(plot_title)
    sns.countplot(data=df, x=x_val)
    plt.show()

# %%
# Reading and storing the dataset in dataframe format and storing in df
df = pd.read_csv('/content/archive.zip')

# returns first 5 rows of dataframe
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
pd.DataFrame(list(df.columns), columns=['Column Name'])
df.shape
# Out:
# (14620, 23)

# %%
# returns the information of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
#Handling missing values
df.isnull()
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 0      False  False               False                False        False
# 1      False  False               False                False        False
# 2      False  False               False                False        False
# 3      False  False               False                False        False
# 4      False  False               False                False        False
# ...      ...    ...                 ...                  ...          ...
# 14615  False  False               False                False        False
# 14616  False  False               False                False        False
# 14617  False  False               False                False        False
# 14618  False  False               False                False        False
# 14619  False  False               False                False        False
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
countplot(dataframe=df, x_val='number of bedrooms', plot_title='Count of Number of Bedrooms')

# %%
# returns the countplot of bathrooms

countplot(dataframe=df, x_val='number of bathrooms', plot_title='Count of Number of Bathrooms')

# %%
# returns the histplot of distance from airport
#UNIVARIATE EDA

sns.histplot(data=df, x='Distance from the airport')
plt.show()

# %%
# displays box plot of each features

fig = plt.figure(figsize = [30, 18])
for i in range(1, len(list(df.columns))):
    plt.subplot(6, 4, i)
    fig.tight_layout(pad=2)
    df_new = df.iloc[:,i]
    plt.suptitle('Comparision of all Features')
    plt.title(list(df.columns)[i])
    sns.boxenplot(df_new)
plt.show()

# %%
sns.barplot(data=df, x='Number of schools nearby', y='Distance from the airport')
plt.title('Number of schools vs Distance from airport')
plt.show()

# %%
sns.barplot(data=df, x='condition of the house', y='number of views')
# Out:
# <Axes: xlabel='condition of the house', ylabel='number of views'>

# %%
#DESCRIPTIVE STATISTICS
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...
